# %%
import pandas as pd


file_path = "./data/Online Retail.xlsx"

data_frame = pd.read_excel(file_path)
print('dataFrame.shape: ', data_frame.shape)
data_frame
# Out:
# dataFrame.shape:  (541909, 8)
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
data_frame.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
data_frame.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# # Task 1: Data Preprocessing

# %% [markdown]
# ## Missing Values

# %%
data_frame.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# For this experiment we will not be looking for the Description and the missing values in the CustomerId

# %%
data_frame.dropna(inplace=True, axis=0)
print('dataFrame.shape: ', data_frame.shape)
data_frame
# Out:
# dataFrame.shape:  (406829, 8)
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
data_frame.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# So now we do not have any missing values

# %% [markdown]
# ### Convert categorical variables into numerical representations if necessary

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %% [markdown]
# I do not think we need to change any categorical value to numerical value
#
# For the InvoiceNo. some of the values are alpha numeric

# %% [markdown]
# ### Remove duplicate records

# %%
data_frame = data_frame.drop_duplicates(keep='first')

print('dataFrame.shape: ', data_frame.shape)
data_frame
# Out:
# dataFrame.shape:  (401604, 8)
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# Extract and create new features, such as 'Total Price' = Quantity \* UnitPrice

# %%
data_frame['Total Price'] = data_frame['Quantity'] * data_frame['UnitPrice']

mean_total_price = data_frame['Total Price'].mean()
data_frame['Is_High_Value'] = (data_frame['Total Price'] > mean_total_price).astype(int)

data_frame
# Out:
# /var/folders/pz/45l1b5fj5jn_1q55dmlkmj_h0000gn/T/ipykernel_9764/1155647343.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['Total Price'] = data_frame['Quantity'] * data_frame['UnitPrice']
# /var/folders/pz/45l1b5fj5jn_1q55dmlkmj_h0000gn/T/ipykernel_9764/1155647343.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['Is_High_Value'] = (data_frame['Total Price'] > mean_total_price).astype(int)
# ...

# %%
from sklearn.preprocessing import StandardScaler

numerical_columns = ['Quantity', 'UnitPrice', 'Total Price']
scaler = StandardScaler()
data_frame[numerical_columns] = scaler.fit_transform(data_frame[numerical_columns])

print("\nNormalized numerical features:")
data_frame[numerical_columns].describe()
# Out:
# Normalized numerical features:
#            Quantity     UnitPrice   Total Price
# count  4.016040e+05  4.016040e+05  4.016040e+05
# mean  -1.431029e-18 -2.916794e-17 -1.193174e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00
# min   -3.236627e+02 -4.979741e-02 -3.915175e+02
# 25%   -4.068708e-02 -3.187984e-02 -3.802387e-02
# 50%   -2.870063e-02 -2.184601e-02 -2.071245e-02
# 75%   -7.322622e-04  3.955286e-03 -1.890635e-03
# max    3.235653e+02  5.585482e+02  3.914217e+02
# /var/folders/pz/45l1b5fj5jn_1q55dmlkmj_h0000gn/T/ipykernel_9764/1405364436.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame[numerical_columns] = scaler.fit_transform(data_frame[numerical_columns])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the plotting style
plt.style.use("seaborn-v0_8-whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('Feature Distributions and Relationships', fontsize=16)

# Distribution of normalized numerical features
sns.histplot(data=data_frame['Quantity'], ax=axes[0,0], kde=True)
axes[0,0].set_title('Distribution of Normalized Quantity')
axes[0,0].set_xlabel('Normalized Quantity')

sns.histplot(data=data_frame['UnitPrice'], ax=axes[0,1], kde=True) 
axes[0,1].set_title('Distribution of Normalized Unit Price')
axes[0,1].set_xlabel('Normalized Unit Price')

# Scatter plot of Quantity vs UnitPrice
sns.scatterplot(data=data_frame, x='Quantity', y='UnitPrice', hue='Is_High_Value', 
                alpha=0.5, ax=axes[1,0])
axes[1,0].set_title('Quantity vs Unit Price')

# Box plot of Total Price by Country
sns.boxplot(data=data_frame, y='Total Price', x='Country', ax=axes[1,1])
axes[1,1].set_title('Total Price Distribution by Country')
axes[1,1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary Statistics by Country:")
print(data_frame.groupby('Country')[numerical_columns].agg(['mean', 'std', 'count']))

print("\nHigh Value Orders by Country:")
print(data_frame.groupby('Country')['Is_High_Value'].value_counts(normalize=True).unstack())
# Out:
# Summary Statistics by Country:
#                       Quantity                   UnitPrice                    \
#                           mean       std   count      mean       std   count
# Country
# Australia             0.216977  0.390410    1258 -0.003673  0.178604    1258
# Austria              -0.000583  0.086884     401  0.011025  0.105429     401
# Bahrain               0.012429  0.099725      17  0.016772  0.052658      17
# Belgium              -0.003969  0.054344    2069  0.002441  0.060841    2069
# Brazil               -0.004228  0.033869      32  0.014079  0.040590      32
# Canada                0.024431  0.186519     151  0.036642  0.640928     151
# Channel Islands       0.001321  0.090236     757  0.020962  0.222998     757
# Cyprus               -0.007507  0.093673     611  0.041228  0.324197     611
# Czech Republic        0.030166  0.091153      30 -0.007679  0.101755      30
# Denmark               0.035422  0.109486     389 -0.003112  0.056767     389
# ...

# %% [markdown]
# # Customer Clustering using K-Means

# %% [markdown]
# Select relevant features for clustering

# %%
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

# Select features for clustering
clustering_features = ['Quantity', 'UnitPrice', 'Total Price']

# Normalize the selected features
scaler = StandardScaler()
data_frame[clustering_features] = scaler.fit_transform(data_frame[clustering_features])

# Apply K-Means clustering
kmeans = KMeans(n_clusters=5, random_state=42)
data_frame['Cluster'] = kmeans.fit_predict(data_frame[clustering_features])

print(data_frame[['CustomerID', 'Cluster']].head(10))

# Create a figure with 3D plot for cluster visualization
fig = plt.figure(figsize=(15, 10))

# 3D scatter plot showing all three features colored by cluster
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(data_frame['Quantity'], 
                    data_frame['UnitPrice'], 
                    data_frame['Total Price'],
                    c=data_frame['Cluster'],
                    cmap='Accent',
                    alpha=0.6)

ax.set_xlabel('Quantity')
ax.set_ylabel('Unit Price')
ax.set_zlabel('Total Price')
ax.set_title('3D Visualization of Customer Clusters')

# Add a color bar
plt.colorbar(scatter, label='Cluster')

# Adjust the viewing angle for better visualization
ax.view_init(elev=20, azim=45)

plt.tight_layout()
plt.show()

# Print cluster statistics
print("\nCluster Statistics:")
print(data_frame.groupby('Cluster')[clustering_features].agg(['mean', 'std']).round(2))
# Out:
# /var/folders/pz/45l1b5fj5jn_1q55dmlkmj_h0000gn/T/ipykernel_9764/1443779606.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame[clustering_features] = scaler.fit_transform(data_frame[clustering_features])
# /var/folders/pz/45l1b5fj5jn_1q55dmlkmj_h0000gn/T/ipykernel_9764/1443779606.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['Cluster'] = kmeans.fit_predict(data_frame[clustering_features])
#    CustomerID  Cluster
# 0     17850.0        0
# ...

# %% [markdown]
# Normalize the features before applying K-Means

# %%
# Select additional features for customer segmentation
clustering_features = ['Quantity', 'UnitPrice', 'Total Price', 'Is_High_Value']

# Normalize the features again with the new selection
scaler = StandardScaler()
data_frame[clustering_features] = scaler.fit_transform(data_frame[clustering_features])

# Apply K-Means clustering with the updated features
kmeans = KMeans(n_clusters=5, random_state=42)
data_frame['Cluster'] = kmeans.fit_predict(data_frame[clustering_features])

# Print cluster statistics for the new features
print("\nUpdated Cluster Statistics:")
print(data_frame.groupby('Cluster')[clustering_features].agg(['mean', 'std']).round(2))

# Create a pair plot to visualize relationships between features
plt.figure(figsize=(15, 12))
for i in range(5):
    cluster_data = data_frame[data_frame['Cluster'] == i]
    plt.subplot(2, 3, i+1)
    plt.scatter(cluster_data['Quantity'], cluster_data['Total Price'], alpha=0.5)
    plt.title(f'Cluster {i}')
    plt.xlabel('Quantity')
    plt.ylabel('Total Price')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/pz/45l1b5fj5jn_1q55dmlkmj_h0000gn/T/ipykernel_9764/3505135181.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame[clustering_features] = scaler.fit_transform(data_frame[clustering_features])
# /var/folders/pz/45l1b5fj5jn_1q55dmlkmj_h0000gn/T/ipykernel_9764/3505135181.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame['Cluster'] = kmeans.fit_predict(data_frame[clustering_features])
# Updated Cluster Statistics:
# ...

# %% [markdown]
# Use the Elbow Method to determine the optimal number of clusters

# %%
import numpy as np
# Apply the Elbow Method to find optimal number of clusters
inertias = []
K = range(1, 11)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data_frame[clustering_features])
    inertias.append(kmeans.inertia_)

# Plot the elbow curve
plt.figure(figsize=(10, 6))
plt.plot(K, inertias, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.grid(True)
plt.show()

# Calculate the rate of inertia change
inertia_changes = np.diff(inertias)
relative_changes = inertia_changes[:-1] / inertia_changes[1:]

print("\nRelative changes in inertia between consecutive k values:")
for k, change in enumerate(relative_changes, start=1):
    print(f"k={k+1}: {change:.2f}")
# Out:
# Relative changes in inertia between consecutive k values:
# k=2: 0.88
# k=3: 1.14
# k=4: 1.11
# k=5: 5.53
# k=6: 2.53
# k=7: 1.00
# k=8: 1.33
# k=9: 2.53

# %% [markdown]
# Apply the K-Means algorithm and interpret the clusters

# %%
# Apply K-means with the optimal number of clusters (k=5 based on elbow method)
kmeans = KMeans(n_clusters=5, random_state=42)
data_frame['Cluster'] = kmeans.fit_predict(data_frame[clustering_features])

# Calculate cluster centers and sizes
cluster_centers = kmeans.cluster_centers_
cluster_sizes = data_frame['Cluster'].value_counts().sort_index()

print("\nCluster Sizes:")
for cluster, size in cluster_sizes.items():
    print(f"Cluster {cluster}: {size} samples ({size/len(data_frame)*100:.1f}%)")

# Calculate mean values for key features in each cluster
cluster_means = data_frame.groupby('Cluster')[clustering_features].mean()
print("\nCluster Centers (Mean Values):")
print(cluster_means)

# Interpret clusters
print("\nCluster Interpretation:")
for i in range(5):
    print(f"\nCluster {i}:")
    print("Characteristics:")
    for feature in clustering_features:
        value = cluster_means.loc[i, feature]
        if abs(value) > 0.5:  # Only show significant deviations from mean
            magnitude = "high" if value > 0 else "low"
            print(f"- {magnitude.capitalize()} {feature}")
# Out:
# Cluster Sizes:
# Cluster 0: 319644 samples (79.6%)
# Cluster 1: 81955 samples (20.4%)
# Cluster 2: 2 samples (0.0%)
# Cluster 3: 2 samples (0.0%)
# Cluster 4: 1 samples (0.0%)
#
# Cluster Centers (Mean Values):
#            Quantity   UnitPrice  Total Price  Is_High_Value
# Cluster
# 0         -0.023830   -0.008224    -0.029091      -0.506354
# 1          0.092945    0.025263     0.114570       1.974872
# 2       -310.118020   -0.027436  -285.457728      -0.506354
# 3        310.020664   -0.027436   285.361929       1.974902
# 4         -0.052674  558.548175   -90.601746      -0.506354
#
# Cluster Interpretation:
#
# Cluster 0:
# Characteristics:
# - Low Is_High_Value
#
# Cluster 1:
# Characteristics:
# - High Is_High_Value
#
# Cluster 2:
# Characteristics:
# - Low Quantity
# - Low Total Price
# - Low Is_High_Value
#
# Cluster 3:
# Characteristics:
# - High Quantity
# - High Total Price
# - High Is_High_Value
#
# Cluster 4:
# Characteristics:
# - High UnitPrice
# - Low Total Price
# ...

# %% [markdown]
# Visualize the clustering results using scatter plots

# %%
# Create scatter plots to visualize clusters
plt.figure(figsize=(15, 10))

# Plot 1: Quantity vs UnitPrice
plt.subplot(2, 2, 1)
scatter = plt.scatter(data_frame['Quantity'], data_frame['UnitPrice'], 
                     c=data_frame['Cluster'], cmap='viridis', alpha=0.5)
plt.xlabel('Quantity')
plt.ylabel('UnitPrice')
plt.title('Clusters: Quantity vs UnitPrice')
plt.colorbar(scatter)

# Plot 2: Quantity vs Total Price
plt.subplot(2, 2, 2)
scatter = plt.scatter(data_frame['Quantity'], data_frame['Total Price'],
                     c=data_frame['Cluster'], cmap='viridis', alpha=0.5)
plt.xlabel('Quantity')
plt.ylabel('Total Price')
plt.title('Clusters: Quantity vs Total Price')
plt.colorbar(scatter)

# Plot 3: UnitPrice vs Total Price
plt.subplot(2, 2, 3)
scatter = plt.scatter(data_frame['UnitPrice'], data_frame['Total Price'],
                     c=data_frame['Cluster'], cmap='viridis', alpha=0.5)
plt.xlabel('UnitPrice')
plt.ylabel('Total Price')
plt.title('Clusters: UnitPrice vs Total Price')
plt.colorbar(scatter)

plt.tight_layout()
plt.show()

# %% [markdown]
# Discuss how businesses can use customer segmentation insights

# %%
# Calculate and print silhouette score
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(data_frame[clustering_features], data_frame['Cluster'])
print(f"\nSilhouette Score: {silhouette_avg:.3f}")

# Interpret the score
print("\nInterpretation:")
if silhouette_avg > 0.5:
    print("Good clustering quality - clusters are well separated")
elif silhouette_avg > 0.25:
    print("Moderate clustering quality - some overlap between clusters")
else:
    print("Poor clustering quality - significant overlap between clusters")
# Out:
# Silhouette Score: 0.955
#
# Interpretation:
# Good clustering quality - clusters are well separated
